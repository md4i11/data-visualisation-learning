# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Build dataframe with image paths & labels
data_dir = "covid-chest-xray-image-dataset"
img_paths, labels = [], []

for label in ["COVID", "Normal", "Pneumonia"]:
    folder = os.path.join(data_dir, label)
    for img in os.listdir(folder):
        img_paths.append(os.path.join(folder, img))
        labels.append(label)

df = pd.DataFrame({"path": img_paths, "label": labels})
print(df["label"].value_counts())

# Bar chart
df["label"].value_counts().plot(kind="bar")
plt.title("Image Count per Class")
plt.show()
